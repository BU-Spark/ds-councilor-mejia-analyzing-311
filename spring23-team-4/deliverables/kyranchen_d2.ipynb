# %%
import pandas as pd

df_2010 = pd.read_csv("311 Cases 2010_2014 Unrestricted.csv")

df_2010.groupby(by="TYPE").size().sort_values(ascending=False)
# Out:
# TYPE
# General Request                    103342
# Schedule a Bulk Item Pickup         93881
# Pothole Repair (Internal)           37889
# Street Light Outages                34766
# Request for Snow Plowing            33382
#                                     ...
# Special Request                         1
# Oil Truck - No Price Per Gallon         1
# Bicycle Issues                          1
# Snow Emergency                          1
# Traffic Signal Inspection               1
# Length: 233, dtype: int64

# %%
df_2020 = pd.read_csv("311 Cases 2020_2024 Unrestricted.csv")

df_2020.groupby(by="TYPE").size().sort_values(ascending=False)
# Out:
# /var/folders/w8/_0qs3h2d4mn4tmbry_ljfzjc0000gn/T/ipykernel_68379/1181443756.py:1: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2020 = pd.read_csv("311 Cases 2020_2024 Unrestricted.csv")
# TYPE
# Parking Enforcement                            95685
# General Request                                94742
# Requests for Street Cleaning                   38047
# Missed Trash/Recycling/Yard Waste/Bulk Item    25666
# Improper Storage of Trash (Barrels)            25553
#                                                ...
# Sign Shop WO                                       1
# Breathe Easy                                       1
# Sidewalk Repair (Internal)                         1
# Accident Claim                                     1
# MBTA Request                                       1
# Length: 193, dtype: int64

# %%
block_group_data = pd.read_csv("census-block-group-data.csv")

block_group_data.head()
# Out:
#           FILEID                        STUSAB         SUMLEV  \
# 0  field concept  State/US-Abbreviation (USPS)  Summary Level
# 1           PLST                            MA            150
# 2           PLST                            MA            150
# 3           PLST                            MA            150
# 4           PLST                            MA            150
#
#                           GEOID                     GEOCODE  REGION  DIVISION  \
# 0  Geographic Record Identifier  Geographic Code Identifier  Region  Division
# 1         1500000US250250001011                    2.50E+11       1         1
# 2         1500000US250250001012                    2.50E+11       1         1
# 3         1500000US250250001021                    2.50E+11       1         1
# 4         1500000US250250001022                    2.50E+11       1         1
#
#           STATE         COUNTY                     COUSUB  ...  \
# ...

# %%
svi = pd.read_csv("Climate_Ready_Boston_Social_Vulnerability.csv")

svi.nlargest(10, "OlderAdult")
# Out:
#      FID      GEOID10    AREA_SQFT  AREA_ACRES  POP100_RE  HU100_RE  TotDis  \
# 112  113  25025000401   4639384.10    106.5056       5672      2965     887
# 31    32  25025130100  47252103.12   1084.7590       5906      2816     702
# 18    19  25025140400  20351684.25    467.2104       7650      2906     760
# 19    20  25025140300  17100930.39    392.5833       6382      2525     983
# 49    50  25025030300   7441425.20    170.8316       4872      2960     678
# 15    16  25025110607  12606722.98    289.4105       5077      2227     486
# 36    37  25025110601  15228405.80    349.5961       2969      1295     335
# 8      9  25025000504   3586159.72     82.3269       4985      2726     700
# 28    29  25025130402  24463363.16    561.6015       4637      2196     614
# 120  121  25025070101  10969123.93    251.8164       5902      3383     457
#
#      TotChild  OlderAdult  Low_to_No   LEP  POC2  MedIllnes              Name  \
# ...

# %%
import matplotlib.pyplot as plt
olderadult_request = pd.read_csv("Olderadult_request.csv")

plt.title("Top 10 OlderAdult Districts")
plt.bar(olderadult_request["Name"],olderadult_request["count(Climate_Ready_Boston_Social_Vulnerability.Name)"], width=0.4)
plt.savefig("OlderAdult.png", bboxinches="tight")
# Out:
# /Users/kyranchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bboxinches" which is no longer supported as of 3.3 and will become an error two minor releases later

# %% [markdown]
# 180, 106, 163, 44, 24, 81, 20, 162, 90, 43, 41, 26, 113, 132, 136, 48, 82, 85, 81, 19, 82, 163, 24, 138, 85, 102, 47, 26, 41, 22, 162, 180, 106, 90, 52, 177, 113, 32, 19, 20, 50, 16, 37, 9, 29, 121, 180, 43, 24, 48, 31, 22, 44, 104, 64, 163, 180, 81, 132, 106, 2, 82, 150, 41, 71, 90, 47, 123, 89, 9, 158, 76, 180, 163, 64, 132, 81, 113, 106, 9, 47, 19, 82, 41, 120, 90, 102, 150, 2, 71, 19, 81, 44, 82, 20, 26, 163, 43, 85, 106, 162, 180, 41, 27, 138, 171, 64, 86, 64, 19, 20, 100, 113, 121, 32, 12, 36, 47, 106, 2, 50, 16, 24, 44, 22, 155

# %%
svi_numbers = [180, 106, 163, 44, 24, 81, 20, 162, 90, 43, 41, 26, 113, 132, 136, 48, 82, 85, 81, 19, 82, 163, 24, 138, 85, 102, 47, 26, 41, 22, 162, 180, 106, 90, 52, 177, 113, 32, 19, 20, 50, 16, 37, 9, 29, 121, 180, 43, 24, 48, 31, 22, 44, 104, 64, 163, 180, 81, 132, 106, 2, 82, 150, 41, 71, 90, 47, 123, 89, 9, 158, 76, 180, 163, 64, 132, 81, 113, 106, 9, 47, 19, 82, 41, 120, 90, 102, 150, 2, 71, 19, 81, 44, 82, 20, 26, 163, 43, 85, 106, 162, 180, 41, 27, 138, 171, 64, 86, 64, 19, 20, 100, 113, 121, 32, 12, 36, 47, 106, 2, 50, 16, 24, 44, 22, 155]
svi_dict = dict()

for item in svi_numbers:
    if item in svi_dict.keys():
        svi_dict[item] += 1
    else:
        svi_dict[item] = 1
# print(len(svi_numbers))
# print(svi_dict)

top_svi = list()

for item, key in svi_dict.items():
    if key >= 4:
        top_svi.append([item, key])

print(top_svi)
# Out:
# [[180, 6], [106, 6], [163, 5], [44, 4], [24, 4], [81, 5], [20, 4], [90, 4], [41, 5], [113, 4], [82, 5], [19, 5], [47, 4], [64, 4]]

# %%
svi_requests = pd.read_csv("svi_requests.csv")

plt.title("Top SVI Index Requests")
plt.bar(svi_requests["Name"],svi_requests["Requests"], width=0.4)
plt.savefig("SVI Index Requests.png", bboxinches="tight")
# Out:
# /Users/kyranchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bboxinches" which is no longer supported as of 3.3 and will become an error two minor releases later
#   """

# %%
svi = pd.read_csv("id_requests_index.csv")
svi["SVI_Index"] = svi["SVI_Index"].fillna(0)
svi.head()

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
i = range(180)
# make a plot
ax.plot(i, 
        svi.Requests,
        color="red", 
        marker="o")
# set x-axis label
ax.set_xlabel("GEOID", fontsize = 14)
# set y-axis label
ax.set_ylabel("Requests",
              color="red",
              fontsize=14)

# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(i, svi.SVI_Index,color="blue",marker="o")
ax2.set_ylabel("svi index",color="blue",fontsize=14)
plt.show()
# save the plot as a file
fig.savefig('id_request_index.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
