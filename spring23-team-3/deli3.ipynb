# %%
# load df
import pandas as pd

df_temp = pd.read_csv('311 Cases with Blocks.csv')

df_temp.head()
# Out:
#    Unnamed: 0  CASE_ENQUIRY_ID OPEN_DT                            SUBJECT  \
# 0           0     1.010030e+11  1/1/20            Mayor's 24 Hour Hotline
# 1           1     1.010030e+11  1/1/20            Mayor's 24 Hour Hotline
# 2           2     1.010030e+11  1/1/20  Transportation - Traffic Division
# 3           3     1.010030e+11  1/1/20  Transportation - Traffic Division
# 4           4     1.010030e+11  1/1/20  Transportation - Traffic Division
#
#                              REASON                TYPE  \
# 0                 Abandoned Bicycle   Abandoned Bicycle
# 1                 Abandoned Bicycle   Abandoned Bicycle
# 2  Enforcement & Abandoned Vehicles  Abandoned Vehicles
# 3  Enforcement & Abandoned Vehicles  Abandoned Vehicles
# 4  Enforcement & Abandoned Vehicles  Abandoned Vehicles
#
#                                             LOCATION   propid  \
# 0                   70 Burbank St, Boston, MA  02115  A162736
# 1           461 Gallivan Blvd, Dorchester, MA  02124   A62325
# 2  INTERSECTION of Milwood St & Gallivan Blvd, Do...   I11942
# 3                10 Stanbro St, Hyde Park, MA  02136  A130087
# 4             8 Pleasanton St, Dorchester, MA  02121  A111359
#
#              SOURCE          X  ...  HOUSING  UNCIVILUSE  BIGBUILD  GRAFFITI  \
# 0    Mobile Request -71.088920  ...        0           0         0         0
# 1  Constituent Call -71.057980  ...        0           0         0         0
# 2    Mobile Request -71.057802  ...        0           0         0         0
# 3    Mobile Request -71.132410  ...        0           0         0         0
# 4    Mobile Request -71.087270  ...        0           0         0         0
#
#    TRASH  PRIVATENEGLECT  PUBLICDENIG PROBLEM CLOSED_DT  BLOCK_ID
# 0      1               0            1       1   3/12/20       NaN
# 1      1               0            1       1   1/13/20    5005.0
# 2      0               0            0       0   1/13/20       NaN
# 3      0               0            0       0   1/18/20    2018.0
# 4      0               0            0       0    1/2/20    3006.0
#
# [5 rows x 30 columns]

# %%
df = pd.read_csv('311 Cases 2020_2024 Unrestricted.csv')

df.head()
# Out:
# /var/folders/s7/dr2xzlzs0vsgkdwm23v3hgk40000gn/T/ipykernel_49258/2198110673.py:1: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('311 Cases 2020_2024 Unrestricted.csv')
#    CASE_ENQUIRY_ID     OPEN_DT                            SUBJECT  \
# 0     101003148635  2020-01-01            Mayor's 24 Hour Hotline
# 1     101003148558  2020-01-01            Mayor's 24 Hour Hotline
# 2     101003148571  2020-01-01  Transportation - Traffic Division
# 3     101003148542  2020-01-01  Transportation - Traffic Division
# 4     101003148439  2020-01-01  Transportation - Traffic Division
#
#                              REASON                TYPE  \
# 0                 Abandoned Bicycle   Abandoned Bicycle
# 1                 Abandoned Bicycle   Abandoned Bicycle
# 2  Enforcement & Abandoned Vehicles  Abandoned Vehicles
# 3  Enforcement & Abandoned Vehicles  Abandoned Vehicles
# 4  Enforcement & Abandoned Vehicles  Abandoned Vehicles
#
#                                             LOCATION   propid  \
# 0                   70 Burbank St, Boston, MA  02115  A162736
# 1           461 Gallivan Blvd, Dorchester, MA  02124   A62325
# 2  INTERSECTION of Milwood St & Gallivan Blvd, Do...   I11942
# 3                10 Stanbro St, Hyde Park, MA  02136  A130087
# 4             8 Pleasanton St, Dorchester, MA  02121  A111359
#
#              SOURCE          X          Y  ...  PUBLIC  HOUSING  UNCIVILUSE  \
# 0    Mobile Request -71.088920  42.344290  ...       1        0           0
# 1  Constituent Call -71.057980  42.282010  ...       1        0           0
# 2    Mobile Request -71.057802  42.282298  ...       1        0           0
# 3    Mobile Request -71.132410  42.235530  ...       1        0           0
# 4    Mobile Request -71.087270  42.310860  ...       1        0           0
#
#    BIGBUILD  GRAFFITI  TRASH PRIVATENEGLECT PUBLICDENIG  PROBLEM   CLOSED_DT
# 0         0         0      1              0           1        1  2020-03-12
# 1         0         0      1              0           1        1  2020-01-13
# 2         0         0      0              0           0        0  2020-01-13
# 3         0         0      0              0           0        0  2020-01-18
# 4         0         0      0              0           0        0  2020-01-02
#
# [5 rows x 28 columns]

# %%
columns = df.loc[(df['CLOSED_DT'].isna() == False)]

# %%
columns.groupby('REASON').size()
# Out:
# REASON
# Abandoned Bicycle                      1693
# Administrative & General Requests      2290
# Air Pollution Control                    72
# Alert Boston                              5
# Animal Issues                          3956
# Billing                                   2
# Boston Bikes                             77
# Bridge Maintenance                       14
# Building                              14426
# Catchbasin                              338
# Cemetery                                 52
# Code Enforcement                      47044
# Consumer Affairs Issues                   1
# Disability                              574
# Employee & General Comments            2898
# Enforcement & Abandoned Vehicles     102394
# Environmental Services                 8262
# Fire Hydrant                            143
# General Request                       56534
# Generic Noise Disturbance               118
# Graffiti                               6567
# Health                                 3937
# Highway Maintenance                   28836
# Housing                                7131
# Massport                                  2
# Needle Program                        21952
# Neighborhood Services Issues             47
# Noise Disturbance                       120
# Notification                           1439
# Office of The Parking Clerk              48
# Operations                              170
# Park Maintenance & Safety             12163
# Parking Complaints                       12
# Pothole                                  39
# Programs                                 25
# Recycling                             26514
# Sanitation                            62530
# School Department                       111
# School Transportation                    25
# Sidewalk Cover / Manhole                238
# Signs & Signals                       19611
# Street Cleaning                       67244
# Street Lights                         15863
# Traffic Management & Engineering        860
# Trees                                 18713
# Weights and Measures                    155
# dtype: int64

# %%
df.groupby('REASON').size()
# Out:
# REASON
# Abandoned Bicycle                      1959
# Administrative & General Requests      3209
# Air Pollution Control                   140
# Alert Boston                              8
# Animal Issues                          7345
# Billing                                  12
# Boston Bikes                             91
# Bridge Maintenance                       19
# Building                              18456
# Catchbasin                             1139
# Cemetery                                 58
# Code Enforcement                      47347
# Consumer Affairs Issues                  28
# Disability                              800
# Employee & General Comments            4052
# Enforcement & Abandoned Vehicles     105628
# Environmental Services                 8490
# Fire Department                           6
# Fire Hydrant                            389
# General Request                       94983
# Generic Noise Disturbance               283
# Graffiti                               8671
# Health                                 4032
# Highway Maintenance                   41448
# Housing                               12018
# MBTA                                      1
# Massport                                 88
# Needle Program                        21975
# Neighborhood Services Issues             76
# Noise Disturbance                      1131
# Notification                           1441
# Office of The Parking Clerk              48
# Operations                              325
# Park Maintenance & Safety             14791
# Parking Complaints                       17
# Pothole                                 106
# Programs                                 40
# Recycling                             26525
# Sanitation                            62566
# School Department                       314
# School Transportation                   207
# Sidewalk Cover / Manhole                562
# Signs & Signals                       21754
# Street Cleaning                       71124
# Street Lights                         17091
# Traffic Management & Engineering       1140
# Trees                                 19871
# Valet                                     5
# Weights and Measures                    155
# dtype: int64

# %%
#for reason in columns.groupby('REASON'):
#   print('The proportion of closed cases for reason ', x, ' is ', columns.groupby('REASON')[reason].size() / df.groupby('REASON')[reason].size())

# %%
import matplotlib.pyplot as plt

# extract the zipcodes from the original df_2020
df['Zip Code'] = df['LOCATION'].str.split(' ').str[-1]

columns2 = df.loc[(df['CLOSED_DT'].isna() == False)]

columns2['Zip Code'] = df['LOCATION'].str.split(' ').str[-1]
columns = columns2["REASON"]

# group the dataframes by zip code

df_grouped = df.groupby('Zip Code')
columns_grouped = columns2.groupby('Zip Code')

# count the number of rows (i.e., cases) per zip code
num_cases = df_grouped.size()
num_cases_mod = columns_grouped.size()

# calculate the proportion of unresolved cases
prop_unresolved = columns_grouped.size() / df_grouped.size()
prop_unresolved = prop_unresolved.sort_values(ascending = True)
prop_unresolved.plot(kind='bar')

plt.title('Proportion of Resolved vs Total Cases Based on Zip Code')
plt.xlabel('Zip Code')
plt.ylabel('Proportion')
# Out:
# /var/folders/s7/dr2xzlzs0vsgkdwm23v3hgk40000gn/T/ipykernel_49258/363583236.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2['Zip Code'] = df['LOCATION'].str.split(' ').str[-1]
# Text(0, 0.5, 'Proportion')

# %%
# group the dataframes by reason
df_grouped = df.groupby('REASON')
columns_grouped = columns2.groupby('REASON')

# count the number of rows (i.e., cases) per zip code
num_cases = df_grouped.size()
num_cases_mod = columns_grouped.size()

# calculate the proportion of unresolved cases
prop_unresolved = columns_grouped.size() / df_grouped.size()
prop_unresolved = prop_unresolved.dropna()
prop_unresolved = prop_unresolved.sort_values(ascending = True)

prop_unresolved_top20 = prop_unresolved.head(25)
prop_unresolved_top20.plot(kind='bar')

plt.title('Proportion of Resolved vs Total Cases Based on Reason (Top 25)')
plt.xlabel('Reason')
plt.ylabel('Proportion')
# Out:
# Text(0, 0.5, 'Proportion')

# %%
import matplotlib.pyplot as plt
import pandas as pd

fall = "311_all.csv"
fclosed = "311_closed.csv"

df_orig = pd.read_csv(fall)
df = pd.read_csv(fall)
closed_data = df[df['CLOSED_DT'].notnull()]
closed_data.to_csv(fclosed, index=False)
cdf = pd.read_csv(fclosed)

pdf = cdf.groupby('BLOCK_ID').agg('count')/df.groupby('BLOCK_ID').agg('count')
pdf = pdf[['Unnamed: 0']]
pdf.rename(columns={'Unnamed: 0': 'Proportions'}, inplace = True)
pdf = pdf[pdf['Proportions'].notnull()]

pdf = pdf.reset_index().rename(columns={'index': 'BLOCK_ID'})
pdf['BLOCK_ID'] = pdf['BLOCK_ID'].astype(str).str.slice(stop=-2)
pdf = pdf.sort_values(by='Proportions')
# pdf.to_csv("/content/block.csv", index=False)
plt.bar(pdf['BLOCK_ID'][:25], pdf['Proportions'][:25] )
plt.title('Proportions of top 20 resolved Block Id')
plt.xlabel('Block ID')
plt.xticks(rotation=90)
plt.ylabel('Proportion')
plt.show()
# Out:
# /var/folders/s7/dr2xzlzs0vsgkdwm23v3hgk40000gn/T/ipykernel_90962/3824447051.py:22: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.bar(pdf['BLOCK_ID'][:25], pdf['Proportions'][:25] )

# %%
blockReason = df_temp.groupby('BLOCK_ID')['REASON'].size().nlargest(25)
ax = blockReason.plot(kind = 'bar', figsize=(10,6), xlabel='BLOCK_ID', ylabel='Count', title='Reason Counts by BLOCK_ID')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
# grouped_df = df_temp.groupby(['BLOCK_ID', 'REASON']).size().reset_index(name='Count')

# # Pivot DataFrame to put request types as columns
# pivoted_df = grouped_df.pivot(index='BLOCK_ID', columns='REASON', values='Count')

# # Calculate proportions of each request type
# proportions_df = pivoted_df.div(pivoted_df.sum(axis=1), axis=0)

# # Create stacked bar graph
# proportions_df.plot(kind='bar', stacked=True)

# plt.xlabel('Block ID')
# plt.ylabel('Proportion')
# plt.title('Proportion of Requests by Type and Block ID')
#plt.show()

import pandas as pd
import matplotlib.pyplot as plt

grouped_df = df_temp.groupby(['BLOCK_ID', 'REASON']).size().reset_index(name='Count')

# Pivot DataFrame to put request types as columns
pivoted_df = grouped_df.pivot(index='BLOCK_ID', columns='REASON', values='Count')

# Calculate proportions of each request type
proportions_df = pivoted_df.div(pivoted_df.sum(axis=1), axis=0)

# Limit the number of bars displayed by selecting the top N blocks with the highest total counts
N = 20
top_blocks = proportions_df.sum(axis=1).nlargest(N).index
proportions_df = proportions_df.loc[top_blocks]

# Create stacked bar graph
fig, ax = plt.subplots(figsize=(12, 6))  # Increase figure size
proportions_df.plot(kind='bar', stacked=True, ax=ax)

plt.xticks(rotation=45)  # Rotate x-axis labels
plt.xlabel('Block ID')
plt.ylabel('Proportion')
plt.title('Proportion of Requests by Type and Block ID')

# Display legend outside the plot area
ax.legend(bbox_to_anchor=(1.04, 1), loc="upper left", title="Reason")

plt.show()
